# %%
import argparse
import time
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

import cv2
import torch
import torch.backends.cudnn as cudnn
from numpy import random
import numpy as np
import os
import io
from PIL import Image

from inference import test
from models.experimental import attempt_load
from utils.datasets import LoadStreams, LoadImages
from utils.general import check_img_size, check_requirements, check_imshow, non_max_suppression, apply_classifier, \
    scale_coords, xyxy2xywh, strip_optimizer, set_logging, increment_path
from utils.plots import plot_one_box
from utils.torch_utils import select_device, load_classifier, time_synchronized, TracedModel

# %%
model_name = 'best.pt'
model = torch.hub.load(os.getcwd(), 'custom', model_name, source ='local', force_reload = True)
model.conf = 0.35
# Out:
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   5                -2  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   6                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   7                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   8                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   9                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  10  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  11                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  12                -1  1         0  models.common.MP                        []
#  13                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  14                -3  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  16          [-1, -3]  1         0  models.common.Concat                    [1]
#  17                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  18                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  19                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  20                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  22                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  23  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  24                -1  1    263168  models.common.Conv                      [512, 512, 1, 1]
#  25                -1  1         0  models.common.MP                        []
#  26                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  27                -3  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  28                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  29          [-1, -3]  1         0  models.common.Concat                    [1]
#  30                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  31                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  32                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  33                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  34                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  35                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  36  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  37                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  38                -1  1         0  models.common.MP                        []
#  39                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  40                -3  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  41                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  42          [-1, -3]  1         0  models.common.Concat                    [1]
#  43                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  44                -2  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  45                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  46                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  47                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  48                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  49  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  50                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  51                -1  1   7609344  models.common.SPPCSPC                   [1024, 512, 1]
#  52                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  53                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  54                37  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  55          [-1, -2]  1         0  models.common.Concat                    [1]
#  56                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  57                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  58                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  59                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  60                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  61                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  62[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  63                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  64                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  65                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  66                24  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  67          [-1, -2]  1         0  models.common.Concat                    [1]
#  68                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  69                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  70                -1  1     73856  models.common.Conv                      [128, 64, 3, 1]
#  71                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  72                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  73                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  74[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  75                -1  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  76                -1  1         0  models.common.MP                        []
#  77                -1  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  78                -3  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  79                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  80      [-1, -3, 63]  1         0  models.common.Concat                    [1]
#  81                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  82                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  83                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  84                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  85                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  86                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  87[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  88                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  89                -1  1         0  models.common.MP                        []
#  90                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  91                -3  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  92                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  93      [-1, -3, 51]  1         0  models.common.Concat                    [1]
#  94                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  95                -2  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  96                -1  1   1180160  models.common.Conv                      [512, 256, 3, 1]
#  97                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  98                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  99                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
# 100[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
# 101                -1  1   1049600  models.common.Conv                      [2048, 512, 1, 1]
# 102                75  1    328704  models.common.RepConv                   [128, 256, 3, 1]
# 103                88  1   1312768  models.common.RepConv                   [256, 512, 3, 1]
# 104               101  1   5246976  models.common.RepConv                   [512, 1024, 3, 1]
# 105   [102, 103, 104]  1     34156  models.yolo.IDetect                     [1, [[12, 16, 19, 36, 40, 28], [36, 75, 76, 55, 72, 146], [142, 110, 192, 243, 459, 401]], [256, 512, 1024]]
# C:\Users\Charles\anaconda3\lib\site-packages\torch\functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:2895.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 415 layers, 37196556 parameters, 37196556 gradients, 105.1 GFLOPS
#
# YOLOR  b792b57 torch 1.12.1+cpu CPU
# Adding autoShape...

# %%
test_dir = r"C:\Users\Charles\Desktop\Springboard\Projects\Capstone_Three\data\cleaned\test\images"

# %cd ..
# %cd data\cleaned\test\images
# Out:
# C:\Users\Charles\Desktop\Springboard\Projects\Capstone_Three
# C:\Users\Charles\Desktop\Springboard\Projects\Capstone_Three\data\cleaned\test\images

# %%
test_image_names = [image for image in os.listdir(test_dir)]

[print(name) for name in test_image_names]
# Out:
# forest-wind-crop-23_jpg.rf.d3f0ca7493c1bec033154f13b576977b.jpg
# forest-wind-crop-9_jpg.rf.c310a43408389c48c031132a41ec1c9e.jpg
# glacier-wind-crop-2_jpg.rf.db62bfccd7e7688926efe8758885ada4.jpg
# naip_1101_CA_WND_i0j1_jpg.rf.eb16d83cbcbbc1556077bf1c887d87bb.jpg
# naip_1133_CA_WND_i0j0_jpg.rf.6462cdc64a46164372e6200ee2d9caa2.jpg
# naip_1148_CA_WND_i0j0_jpg.rf.513433545c3f4c3fc4a62ae0f62775ed.jpg
# naip_1148_CA_WND_i0j1_jpg.rf.9d939b1906ac5fbef1c68aa309953473.jpg
# naip_1149_CA_WND_i0j0_jpg.rf.8d51bafa4d81784a917117bfd02af8cc.jpg
# naip_1149_CA_WND_i1j0_jpg.rf.73783a0dc88ada4918e9c19c68f05874.jpg
# naip_1197_CA_WND_i0j1_jpg.rf.27654b4c3bf87dc13c5575aa876eda25.jpg
# naip_1252_CA_WND_i1j1_jpg.rf.ca5419680784fae1f7ebe6aeb62d6284.jpg
# naip_1265_CA_WND_i0j1_jpg.rf.f423ecb7b7a2cab151c7d72101d1f2ac.jpg
# naip_1353_CA_WND_i0j0_jpg.rf.c8fa7b1269ff693f4d6f1644de316437.jpg
# naip_1353_CA_WND_i1j1_jpg.rf.f893c740e98c2b9c61f5985d49d4cd69.jpg
# naip_1423_CA_WND_i1j1_jpg.rf.50069d8b7caf2b125261edde8f9b5a02.jpg
# naip_1434_CA_WND_i0j1_jpg.rf.3d03a370067f0267155f93b1ad2d9555.jpg
# naip_1486_CA_WND_i0j0_jpg.rf.1b548deda3c533724a2c5eb87f108898.jpg
# naip_1623_CA_WND_i1j1_jpg.rf.5c9d30e414f08d83cdf200370e7b31b5.jpg
# naip_1742_CA_WND_i0j0_jpg.rf.f7427afad86551bc858408261fb8b9cd.jpg
# naip_8010_VT_WND_i0j0_jpg.rf.ff993fb11aba8e23ed33dc8204f6c3a1.jpg
# naip_8010_VT_WND_i0j1_jpg.rf.4d78ec9eb6dadfcae521ac00a7bdc9aa.jpg
# naip_8093_WA_WND_i0j1_jpg.rf.5d14a73ace4f2ff795304e8b65a42dbb.jpg
# naip_8106_WA_WND_i1j1_jpg.rf.e752099d6d490f92538700802a9b1103.jpg
# naip_8109_WA_WND_i1j1_jpg.rf.ec1f56c379fc97cf86cc960d3b78deb1.jpg
# naip_8126_WA_WND_i1j1_jpg.rf.3900c7a2aba35bf303d89a9a2579f1f8.jpg
# naip_819_CA_WND_i1j1_jpg.rf.97c2fdeeea22f605f9f066662c89b974.jpg
# naip_8224_WI_WND_i0j0_jpg.rf.023cbb3c7afd1c5a97019d439e67f597.jpg
# naip_824_CA_WND_i0j0_jpg.rf.3fe00ec46725673c6f00c1d4718aa366.jpg
# naip_8271_WI_WND_i0j0_jpg.rf.46adc4bacdcb55b6d924ef18e6a5fa3e.jpg
# naip_8271_WI_WND_i1j0_jpg.rf.0731fac205d236f192dfb2dd7982ca94.jpg
# naip_8272_WI_WND_i1j0_jpg.rf.92e3fce6c3d0b8151125b5451e61f64c.jpg
# naip_827_CA_WND_i0j1_jpg.rf.abe455b2d04d07633c308e0d0b270877.jpg
# naip_8298_WI_WND_i1j0_jpg.rf.28923c27e91706f88ee294e5c4be833d.jpg
# suburban-wind-21_jpg.rf.586197ed984c9f56c5de54db46ed9373.jpg
# suburban-wind-25_jpg.rf.e5e506a880660a812e09d4a3b54dd1d2.jpg
# suburban-wind-28_jpg.rf.8a70a1f77e08816ecaf957395b524a7a.jpg
# suburban-wind-2_jpg.rf.51e27f9ae45c01a587a3e39151b89a1c.jpg
# suburban-wind-39_jpg.rf.415207042a491261f606a86c0005b452.jpg
# suburban-wind-3_jpg.rf.a506a604ca4a29bc1870da0dec819740.jpg
# suburban-wind-44_jpg.rf.ef1a57a00df868f2e5701e2bdfbe5761.jpg
# suburban-wind-51_jpg.rf.d4a43dec1b9d89001b518704aa441c92.jpg
# suburban-wind-5_jpg.rf.9f96ba7ba194256d2813682cd3273ce0.jpg
# suburban-wind-61_jpg.rf.4282e06dbec22c2f5b928fcdd4470075.jpg
# suburban-wind-68_jpg.rf.15928527cb9e769c4eb4203ca81085ea.jpg
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
test_results = [model(image, size=640) for image in os.listdir(test_dir)]
# Out:
# C:\Users\Charles\anaconda3\lib\site-packages\torch\amp\autocast_mode.py:198: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')

# %%
[test_results[test_results.index(item)].print() for item in test_results] # or .show(), .save(), .crop(), .pandas(), etc.
# Out:
# image 1/1: 640x640 1 turbine
# Speed: 39.0ms pre-process, 2380.3ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 31.3ms pre-process, 2312.5ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2296.9ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 2364.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 2546.9ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 12 turbines
# Speed: 15.6ms pre-process, 3297.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 17 turbines
# Speed: 15.6ms pre-process, 2917.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 6 turbines
# Speed: 15.6ms pre-process, 2437.5ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 4 turbines
# Speed: 31.2ms pre-process, 2387.4ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 20 turbines
# Speed: 15.6ms pre-process, 2390.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 16 turbines
# Speed: 15.6ms pre-process, 2640.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 3139.2ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 5 turbines
# Speed: 31.2ms pre-process, 2515.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 8 turbines
# Speed: 15.6ms pre-process, 2406.2ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2484.4ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 40 turbines
# Speed: 15.6ms pre-process, 2890.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 2968.7ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2812.5ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 5 turbines
# Speed: 15.7ms pre-process, 2359.3ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 16 turbines
# Speed: 15.6ms pre-process, 3070.9ms inference, 3.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 3 turbines
# Speed: 31.0ms pre-process, 3231.9ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 16 turbines
# Speed: 15.6ms pre-process, 2450.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 18 turbines
# Speed: 0.0ms pre-process, 2976.7ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 2621.6ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2403.3ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.7ms pre-process, 2556.6ms inference, 5.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 20.0ms pre-process, 2397.7ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.7ms pre-process, 2445.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 3034.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2808.3ms inference, 1.3ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 14.7ms pre-process, 3858.8ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 3589.2ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 31.2ms pre-process, 2963.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 25.7ms pre-process, 3693.7ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 3078.4ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 21.0ms pre-process, 4123.0ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2950.2ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2722.9ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 3579.8ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 2542.3ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 17.0ms pre-process, 2552.4ms inference, 2.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 17.0ms pre-process, 2555.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 3070.3ms inference, 2.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.0ms pre-process, 3539.8ms inference, 2.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 24.0ms pre-process, 3800.9ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 25.5ms pre-process, 3214.4ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 31.3ms pre-process, 2860.9ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 31.3ms pre-process, 3141.8ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 27.0ms pre-process, 3834.4ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 20.2ms pre-process, 3101.9ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.7ms pre-process, 2936.2ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 3111.4ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 3 turbines
# Speed: 15.6ms pre-process, 2464.4ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 14.0ms pre-process, 3125.5ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 4 turbines
# Speed: 20.0ms pre-process, 3189.0ms inference, 2.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 14.0ms pre-process, 2877.7ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2625.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2453.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 3 turbines
# Speed: 15.6ms pre-process, 2608.6ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 3 turbines
# Speed: 19.0ms pre-process, 3514.0ms inference, 2.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 28.0ms pre-process, 2934.7ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 23.0ms pre-process, 3971.3ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2584.3ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2334.2ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 3012.4ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2861.4ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 2515.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 3 turbines
# Speed: 15.6ms pre-process, 2531.2ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 31.3ms pre-process, 2921.9ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 31.3ms pre-process, 2693.2ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 3333.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 31.3ms pre-process, 2593.8ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2453.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2390.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 31.3ms pre-process, 2437.5ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 31.3ms pre-process, 2375.5ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 3 turbines
# Speed: 15.6ms pre-process, 3252.5ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2609.4ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 9 turbines
# Speed: 15.6ms pre-process, 2377.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 2453.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2421.9ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 31.3ms pre-process, 2508.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 3109.4ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 31.3ms pre-process, 2728.3ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.7ms pre-process, 2453.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.7ms pre-process, 2781.3ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 31.3ms pre-process, 2783.9ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 31.3ms pre-process, 2531.3ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 3375.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2750.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2468.8ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2546.9ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2407.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 0.0ms pre-process, 3046.9ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 31.2ms pre-process, 3640.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 4 turbines
# Speed: 15.6ms pre-process, 2515.6ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2454.7ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 2492.2ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 0.0ms pre-process, 2484.4ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2578.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 3796.9ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 31.3ms pre-process, 3575.2ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2421.9ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 3 turbines
# Speed: 15.6ms pre-process, 2375.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 31.3ms pre-process, 2468.7ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 3062.5ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 2859.4ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2811.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 3 turbines
# Speed: 15.6ms pre-process, 2390.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 17 turbines
# Speed: 15.6ms pre-process, 2385.7ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 4 turbines
# Speed: 15.6ms pre-process, 2390.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.7ms pre-process, 3296.9ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 3062.5ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2670.4ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.7ms pre-process, 2436.7ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2437.5ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2453.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 0.0ms pre-process, 3390.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2546.9ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2417.9ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2509.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2375.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 3 turbines
# Speed: 15.6ms pre-process, 2328.1ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 3281.2ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2640.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 3 turbines
# Speed: 15.6ms pre-process, 2468.8ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2458.3ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2468.4ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2453.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 31.3ms pre-process, 3316.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2840.4ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2950.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2896.7ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2703.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 2703.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 31.3ms pre-process, 2980.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 2599.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2531.3ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2921.9ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2656.3ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2937.5ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2828.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2437.5ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2453.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2546.9ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2390.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.7ms pre-process, 3325.8ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 3322.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2656.2ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 15.6ms pre-process, 2359.4ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.6ms pre-process, 3112.9ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2812.5ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 3 turbines
# Speed: 15.6ms pre-process, 3200.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 0.0ms pre-process, 2593.7ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2383.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2466.7ms inference, 15.6ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 0.0ms pre-process, 2359.4ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640
# Speed: 31.3ms pre-process, 2609.3ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 31.3ms pre-process, 3274.5ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 3 turbines
# Speed: 15.6ms pre-process, 2562.5ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 31.2ms pre-process, 2442.5ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2316.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2515.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.7ms pre-process, 2486.3ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 2 turbines
# Speed: 15.7ms pre-process, 3233.4ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2918.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2831.2ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2531.3ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2526.0ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 15.6ms pre-process, 2890.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 640x640 1 turbine
# Speed: 31.3ms pre-process, 3580.7ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
test_detections = [detection for detection in test_results]
results_df = pd.DataFrame(columns = ['xmin', 'ymin', 'xmax', 'ymax', 'confidence', 'class', 'name', 'image_name'])

for i in range(len(test_detections)):
    temp = test_results[test_results.index(test_detections[i])].pandas().xyxy[0]
    temp['image_name'] = test_image_names[i]
    
    results_df = pd.concat([temp, results_df], ignore_index=False)

# %%
results_df
# Out:
#           xmin        ymin        xmax        ymax confidence class     name  \
# 0   448.500244  213.357697   511.77417  288.904938   0.826158     0  turbine
# 0   437.220032  464.482086  570.175049  566.492676   0.751208     0  turbine
# 0   376.973358  197.685455  435.680084  298.131165   0.524654     0  turbine
# 0    84.116226   17.037342  172.113083  123.228577   0.781259     0  turbine
# 0   528.135742  320.286011  630.408936  431.460205   0.655745     0  turbine
# ..         ...         ...         ...         ...        ...   ...      ...
# 0    134.10556  502.979858  165.347321  521.985596   0.421261     0  turbine
# 1    70.886559  595.191956    88.43969  607.999207   0.361537     0  turbine
# 0   541.074402  344.428101   585.74054  419.613831    0.57474     0  turbine
# 0   225.472183  242.922699  341.873779  290.719818    0.78964     0  turbine
# 0    31.510445   264.87912  123.577736  359.166962   0.649997     0  turbine
#
#                                            image_name
# 0   suburban-wind-68_jpg.rf.15928527cb9e769c4eb420...
# 0   suburban-wind-61_jpg.rf.4282e06dbec22c2f5b928f...
# 0   suburban-wind-5_jpg.rf.9f96ba7ba194256d2813682...
# 0   suburban-wind-51_jpg.rf.d4a43dec1b9d89001b5187...
# 0   suburban-wind-44_jpg.rf.ef1a57a00df868f2e5701e...
# ..                                                ...
# 0   naip_1101_CA_WND_i0j1_jpg.rf.eb16d83cbcbbc1556...
# 1   naip_1101_CA_WND_i0j1_jpg.rf.eb16d83cbcbbc1556...
# 0   glacier-wind-crop-2_jpg.rf.db62bfccd7e7688926e...
# 0   forest-wind-crop-9_jpg.rf.c310a43408389c48c031...
# 0   forest-wind-crop-23_jpg.rf.d3f0ca7493c1bec0331...
#
# [367 rows x 8 columns]

# %%
#os.getcwd()
# Out:
# 'C:\\Users\\Charles\\Desktop\\Springboard\\Projects\\Capstone_Three\\data\\cleaned\\test\\images'

# %%
# ADD CODE TO SHOW SOME DETECTIONS AND EXPORT ALL TO 'data\\results\\'

# %%
detec_by_image = results_df['image_name'].value_counts().reset_index()
conf_by_image = results_df.groupby('image_name')['confidence'].agg(np.mean).reset_index()

# %%
detec_by_image.rename(columns={'index':'image_name','image_name':'count'}, inplace=True)

detec_by_image['image_name'] = detec_by_image['image_name'].astype(str)

# %%
#confidence_count = detec_by_image.join(conf_by_image, on='image_name', how='inner')

confidence_count = pd.merge(detec_by_image, conf_by_image, how="inner", on='image_name')

# %%
confidence_count
# Out:
#                                             image_name  count  confidence
# 0    naip_1434_CA_WND_i0j1_jpg.rf.3d03a370067f02671...     40    0.635876
# 1    naip_1197_CA_WND_i0j1_jpg.rf.27654b4c3bf87dc13...     20    0.683541
# 2    naip_1771_CA_WND_i1j1_jpg.rf.4720ef4be773eca44...     18    0.564923
# 3    naip_1148_CA_WND_i0j1_jpg.rf.9d939b1906ac5fbef...     17    0.517677
# 4    naip_666_CA_WND_i1j0_jpg.rf.7581021bbf72d588dd...     17    0.516747
# ..                                                 ...    ...         ...
# 110  naip_6184_NY_WND_i1j1_jpg.rf.51dd337b173acdfc0...      1    0.735626
# 111  naip_629_CA_WND_i1j1_jpg.rf.caa6a9840f9ef6e626...      1    0.399259
# 112  naip_6569_OK_WND_i0j0_jpg.rf.bbc2dcd1252cfe0db...      1    0.603358
# 113  naip_6999_PA_WND_i1j0_jpg.rf.f4a133b7459119555...      1    0.663935
# 114  forest-wind-crop-23_jpg.rf.d3f0ca7493c1bec0331...      1    0.649997
#
# [115 rows x 3 columns]

# %%
plt.scatter(confidence_count['count'], confidence_count['confidence'])
plt.show()
